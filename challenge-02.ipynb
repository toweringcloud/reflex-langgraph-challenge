# %%
import openai
import os
from dotenv import load_dotenv

load_dotenv()
client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
messages = []

PROMPT = """
너는 사용자의 취향을 기억하는 영화 추천 챗봇이야!
- 사용자가 좋아하는 장르를 기억해줘
- 이미 시청한 영화를 기억해줘
- 대화 기록을 기반으로 추천해줘
"""

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
    )
    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": message})
    print(f"AI: {message}")

# %%
while True:
    message = input("Send a message to the LLM...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({"role": "user", "content": f"{PROMPT}\n{message}"})
        print(f"User: {message}")
        call_ai()
# Out:
# User: 안녕, 난 어드벤처 액션 영화를 좋아해!
# AI: 안녕하세요! 어드벤처 액션 영화를 좋아하신다니 멋지네요! 앞으로 어드벤처 액션 장르에 맞는 영화 추천을 해드릴게요. 혹시 이미 시청한 영화가 있다면 말씀해 주시면 그 영화들을 기반으로 더 좋은 추천을 해드릴 수 있을 거예요! 어떤 영화를 시청하셨나요?
# User: 최근에 아바타3를 봤는데 아바타1과 아바타2에 이어 너무 흥미진진했어~!
# AI: 아바타 시리즈를 다 보셨군요! 정말 흥미로운 어드벤처 액션 영화죠. 그럼 현재 좋아하는 장르는 어드벤처 액션이고, 아바타 1, 2, 3을 모두 시청하셨다는 걸 기억할게요. 이 장르와 비슷한 다른 영화를 추천해드릴게요!
#
# **추천 영화:**
# 1. **아발론 (Avatar)** - 현실과 가상 세계의 경계를 넘는 이야기로 흥미로운 시각적 경험을 제공합니다.
# 2. **인디아나 존스 시리즈 (Indiana Jones Series)** - 고전적인 어드벤처 영화로, 잃어버린 보물과 고대 유적을 탐험하는 흥미진진한 이야기.
# 3. **트랜스포머 시리즈 (Transformers Series)** - 외계 로봇들과의 전투를 다룬 액션으로, 시각적인 스펙타클을 즐길 수 있습니다.
# 4. **가디언즈 오브 갤럭시 (Guardians of the Galaxy)** - 유머와 액션이 어우러진 우주 어드벤처 영화로, 다양한 캐릭터들의 매력을 느낄 수 있습니다.
#
# 이 중에서 어떤 영화가 끌리시나요? 더 많은 추천을 원하시면 언제든지 말씀해 주세요!
# User: 아발론이란 영화를 보고 싶네, 나머지는 모두 봤던거 같고
# AI: 아발론을 보고 싶으시군요! 흥미로운 선택이에요. 아발론은 현실과 가상 현실의 경계를 탐구하는 매력적인 영화입니다.
#
# 현재 좋아하는 장르는 어드벤처 액션이고, 아바타 1, 2, 3과 인디아나 존스, 트랜스포머, 가디언즈 오브 갤럭시를 보셨다는 걸 기억할게요.
#
# 혹시 아발론을 보신 후에 더 많은 영화 추천을 원하셨다면 언제든지 말씀해 주세요! 또 다른 어드벤처 액션 영화가 필요하시면 도와드릴 준비가 되어 있습니다. 즐거운 시청 되세요!
# User: 내가 좋아하는 영화 장르랑, 이미 본 영화가 뭐라고 했지?
# AI: 사용자님이 좋아하는 영화 장르는 **어드벤처 액션**이고, 이미 시청하신 영화는 **아바타 1, 2, 3**와 **인디아나 존스 시리즈**, **트랜스포머 시리즈**, **가디언즈 오브 갤럭시**라고 말씀하셨습니다!
#
# 이 정보를 그대로 기억하고 있으니, 더 많은 추천이나 궁금한 점이 있다면 언제든지 말씀해 주세요!
